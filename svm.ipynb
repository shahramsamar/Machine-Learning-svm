# %%
# import librarty 
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm

# %%
# data frame 

X = np.array([
    [1, 1],
    [0.5, 1], 
    [1, 0],
    [0, 0],
    [3, 3], 
    [3, 4],
    [4, 2] 
])
